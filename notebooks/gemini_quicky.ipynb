# %%
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/documents.readonly"]

# The ID of a sample document.
DOCUMENT_ID = "195j9eDD3ccgjQRttHhJPymLJUCOUjs-jmwTrekvdjFE"


def main():
  """Shows basic usage of the Docs API.
  Prints the title of a sample document.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          ".secrets/google_secrets.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("docs", "v1", credentials=creds)

    # Retrieve the documents contents from the Docs service.
    document = service.documents().get(documentId=DOCUMENT_ID).execute()

    print(f"The title of the document is: {document.get('title')}")
  except HttpError as err:
    print(err)


if __name__ == "__main__":
  main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=375515746597-4670l1fag5u9mpg3df4m5qh5dfh65j61.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A52052%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocuments.readonly&state=pPd0ViYiG9zeOuneJHKqHuFIo7dhDg&access_type=offline
# The title of the document is: Docs API Quickstart

# %%
# Remember to install google gemini API library
# %pip install -q -U google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Could not find platform independent libraries <prefix>

# %%
from google import genai
from dotenv import load_dotenv
import os

load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY") 
client = genai.Client(api_key=gemini_api_key)


response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Explain how AI works",
)

print(response.text)
# Out:
# Okay, let's break down how AI works in a way that's hopefully easy to understand.  It's a big field, so this will be a high-level overview, but it will cover the core concepts.
#
# **What is AI, at its core?**
#
# At its most fundamental level, AI is about creating systems that can perform tasks that typically require human intelligence. This includes things like:
#
# *   **Learning:** Improving performance based on experience.
# *   **Reasoning:**  Solving problems and making decisions.
# *   **Perception:**  Understanding sensory input (like images, sounds, or text).
# *   **Natural Language Processing (NLP):** Understanding and generating human language.
#
# **The Two Main Approaches to AI**
#
# Historically, AI has been approached in two main ways:
#
# 1.  **Symbolic AI (Rule-Based AI or GOFAI - Good Old-Fashioned AI):**
#
#     *   **How it works:**  This approach focuses on representing knowledge explicitly using symbols, rules, and logical reasoning.  Think of it as programming a computer with a detailed set of instructions and facts.
#     *   **Example:** A chess-playing program where the rules of chess are explicitly programmed, and the computer uses algorithms to search for the best move based on those rules.
#     *   **Strengths:**  Good for tasks with well-defined rules and logic.  Explanations are often easier to understand because the reasoning is based on explicit rules.
#     *   **Weaknesses:**  Struggles with tasks that are ambiguous, require common sense, or involve perception (like recognizing objects in images).  Difficult to scale to complex, real-world problems.  Requires extensive manual knowledge engineering.
#
# 2.  **Machine Learning (ML):**
#
#     *   **How it works:**  Instead of explicitly programming rules, Machine Learning algorithms learn from data.  They identify patterns and relationships in the data and use those patterns to make predictions or decisions.
#     *   **Example:** Training an algorithm to recognize cats in images by showing it thousands of images of cats.  The algorithm learns the features that are characteristic of cats.
#     *   **Strengths:**  Excellent for tasks involving pattern recognition, prediction, and dealing with large amounts of data.  Can adapt to new data and improve over time.  Can handle ambiguity and complexity better than symbolic AI.
#     *   **Weaknesses:**  Requires large amounts of training data.  Can be difficult to understand *why* a machine learning model makes a particular decision (the "black box" problem).  Susceptible to biases in the training data.
#
# **Focusing on Machine Learning (Because it's the dominant approach today)**
#
# Since Machine Learning is the most prevalent form of AI in use today, let's dive a bit deeper into how it works.  There are several types of Machine Learning:
#
# *   **Supervised Learning:**
#
#     *   **How it works:**  The algorithm is trained on a labeled dataset, meaning each input data point has a corresponding correct output (or "label").  The algorithm learns to map inputs to outputs.
#     *   **Example:**  Training a spam filter. You provide the algorithm with emails, and you label each email as either "spam" or "not spam" (the labels). The algorithm learns to identify features of spam emails.
#     *   **Common Algorithms:** Linear Regression, Logistic Regression, Support Vector Machines (SVMs), Decision Trees, Random Forests, Neural Networks.
#     *   **Use Cases:** Image classification, fraud detection, predicting customer churn, medical diagnosis.
#
# *   **Unsupervised Learning:**
#
#     *   **How it works:**  The algorithm is trained on an unlabeled dataset.  It has to discover patterns and structures in the data on its own.
#     *   **Example:**  Clustering customers into different segments based on their purchasing behavior.  The algorithm identifies groups of customers with similar characteristics.
#     *   **Common Algorithms:** K-Means Clustering, Hierarchical Clustering, Principal Component Analysis (PCA), Anomaly Detection.
#     *   **Use Cases:** Customer segmentation, anomaly detection, dimensionality reduction, recommendation systems.
#
# *   **Reinforcement Learning:**
#
#     *   **How it works:**  The algorithm learns by interacting with an environment and receiving rewards or penalties for its actions.  It learns to choose actions that maximize its cumulative reward.
#     *   **Example:**  Training a robot to navigate a maze. The robot receives a reward for reaching the goal and a penalty for bumping into walls.  It learns a policy (a set of actions) that leads to the highest reward.
#     *   **Common Algorithms:** Q-Learning, Deep Q-Networks (DQN), Policy Gradients.
#     *   **Use Cases:** Game playing (e.g., AlphaGo), robotics, autonomous driving, resource management.
#
# **Key Components of a Machine Learning System**
#
# Regardless of the type of Machine Learning, most systems have these components:
#
# 1.  **Data:** The raw material for training the algorithm.  The quality and quantity of data are crucial.
# 2.  **Features:**  Relevant attributes or characteristics extracted from the data. Feature engineering (selecting and transforming features) is a critical step.  For example, in image recognition, features might include edges, corners, or textures.  In text analysis, features might include word frequencies or sentiment scores.
# 3.  **Algorithm:**  The mathematical model that learns from the data.
# 4.  **Model:** The trained algorithm. It's the result of the learning process, and it's used to make predictions or decisions on new, unseen data.
# 5.  **Evaluation:**  Assessing the performance of the model using metrics appropriate for the task (e.g., accuracy, precision, recall, F1-score).
# 6.  **Deployment:**  Integrating the model into a real-world application.
# 7.  **Monitoring:**  Continuously tracking the model's performance and retraining it as needed to maintain accuracy and adapt to changing data.
#
# **Deep Learning: A Subfield of Machine Learning**
#
# Deep Learning is a type of Machine Learning that uses artificial neural networks with many layers (hence "deep").  These networks can learn complex patterns and representations from data.
#
# *   **How it works:** Deep neural networks are inspired by the structure of the human brain.  They consist of interconnected nodes (neurons) arranged in layers.  Each connection between neurons has a weight, which is adjusted during the learning process.
# *   **Strengths:**  Exceptional performance on tasks like image recognition, natural language processing, and speech recognition.  Can automatically learn features from raw data, reducing the need for manual feature engineering.
# *   **Weaknesses:**  Requires even more data and computational power than other machine learning methods.  More difficult to interpret and debug than simpler models.  More prone to overfitting (performing well on the training data but poorly on new data).
# *   **Common Architectures:** Convolutional Neural Networks (CNNs), Recurrent Neural Networks (RNNs), Transformers.
#
# **The AI Development Process (Simplified)**
#
# 1.  **Define the problem:** Clearly specify the task you want the AI to solve.
# 2.  **Gather and prepare data:** Collect relevant data, clean it, and prepare it for training.
# 3.  **Choose an algorithm:** Select an appropriate Machine Learning algorithm based on the problem and the data.
# 4.  **Train the model:** Train the algorithm on the training data.
# 5.  **Evaluate the model:** Evaluate the model's performance on a separate test dataset.
# 6.  **Tune the model:** Adjust the model's parameters to improve its performance. This often involves techniques like hyperparameter optimization.
# 7.  **Deploy the model:** Integrate the model into an application or system.
# 8.  **Monitor and maintain the model:** Continuously monitor the model's performance and retrain it as needed.
#
# **Ethical Considerations**
#
# It's important to remember that AI is a powerful technology with significant ethical implications.  Bias in data can lead to unfair or discriminatory outcomes.  AI systems should be developed and used responsibly, with careful consideration of their potential impact on society.
#
# **In Conclusion**
#
# AI is a broad field that encompasses many different techniques and approaches.  Machine Learning, particularly Deep Learning, is currently the most successful and widely used approach.  By understanding the core concepts and principles of AI, you can gain a better appreciation of its capabilities and limitations.  The field is rapidly evolving, so continuous learning is essential.
